# %% [markdown]
# <a href="https://colab.research.google.com/github/sangweon2-art/AI-Workflow-Archive/blob/main/0209_%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EA%B8%B0%EC%B4%88%EA%B0%95%EC%9D%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 를 통해 주석 처리 주석  =메모
korea = "Hellow"
print(variable)
# Out:
# Hellow

# %%
number = 10

print(korea * number)
# Out:
# HellowHellowHellowHellowHellowHellowHellowHellowHellowHellow

# %%
a=10
b=3
print(a**b)
# Out:
# 1000

# %%
number1 = 11
number2 = 4

print('덧셈 결과 : ', number1 + number2)
# Out:
# 덧셈 결과 :  15

# %%
# Out:
# 뺄셈 결과 :  7
# 곱셈 결과 :  44
# 나눗셈 결과 :  2.75

# %%
# 관계 연산자 #

a = 10
b = 5
print(a > b)
print(a<b)

print (a>=b)

a = 10
b = 10
print (a==b)

print(a!=b)
# Out:
# True
# False
# True
# True
# False

# %%
# 논리 연산자 #
# and / or / not #
a= True
b = False
print(a and b)
# Out:
# False

# %%
korea = 3
country = [1,3,5,7,9]
print(korea in country)
# Out:
# True

# %%
# 조건문 #
# if: 조건이 참이면 실행 #


a = 5
if a == 5 :
  print ('정답')
# Out:
# 정답

# %%
a = 3
if a< 42 :
  print('a가 2보다 적다')
# Out:
# a가 2보다 적다

# %%
x = int(input())
if x<0 :
  print('음수')
elif x==0 :
  print('0')
elif 0 < x < 5 :
  print('0보다 크고 5보다 작다')
else :
  print('5보다 크다')
# Out:
# 6
# 5보다 크다

# %%
list_1= [1,2,3,4,5,1,3]
print(list_1)
# Out:
# [1, 2, 3, 4, 5, 1, 3]

# %%
len(list_1)
# Out:
# 7

# %%
list_1[3] = 9999
print(list_1)

list_1.append(100)
print(list_1)
# Out:
# [1, 2, 3, 9999, 5, 1, 3]
# [1, 2, 3, 9999, 5, 1, 3, 100]
